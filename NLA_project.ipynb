# %% [markdown]
# # Проект по Вычислительной Алгебре

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #№ Тестовый датасет fetch_olivetti_faces

# %% [markdown]
# ### Примеры изображений из датасета

# %%
from sklearn.datasets import fetch_olivetti_faces

# Загрузка датасета
data = fetch_olivetti_faces(shuffle=True, random_state=42)

# Получение изображений и меток
images = data.images  # массив изображений размером (400, 64, 64)
targets = data.target  # метки классов (индекс человека)

# Визуализация нескольких изображений из датасета
fig, axes = plt.subplots(1, 10, figsize=(15, 5))
for i, ax in enumerate(axes):
    ax.imshow(images[i], cmap='gray')
    ax.set_title(f"Label: {targets[i]}")
    ax.axis('off')

plt.tight_layout()
plt.savefig('images/olivetti_faces.png', bbox_inches='tight', pad_inches=0.1)
plt.show()

# %% [markdown]
# ### Примеры базисных компонент. Обычный и разряженный SVD дают разные результаты!

# %%
from scipy.linalg import svd
from scipy.sparse.linalg import svds

k = 100 # сколько компонент

U, L, V = svd(images.reshape(400, -1), full_matrices=False)
U_s, L_s, V_s = svds(images.reshape(400, -1), k=k)
components = V[:k].reshape(-1, 64, 64)
components_s = V_s.reshape(-1, 64, 64)

fig, axes = plt.subplots(2, 3, figsize=(5, 3))
axes[0][0].imshow(components[0], cmap='gray')
axes[0][1].imshow(components[1], cmap='gray')
axes[0][2].imshow(components[2], cmap='gray')
axes[1][0].imshow(components_s[0], cmap='gray')
axes[1][1].imshow(components_s[1], cmap='gray')
axes[1][2].imshow(components_s[2], cmap='gray')
axes[0][0].axis('off')
axes[0][1].axis('off')
axes[0][2].axis('off')
axes[1][0].axis('off')
axes[1][1].axis('off')
axes[1][2].axis('off')
# for i, ax in enumerate(axes):
#     ax.imshow(components[i], cmap='gray')
#     ax.axis('off')
# plt.savefig('images/olivetti_faces_SVD.png', bbox_inches='tight', pad_inches=0.1)
# plt.show()

# # fig, axes = plt.subplots(1, 10, figsize=(15, 5))
# for i, ax in enumerate(axes):
#     ax.imshow(components_s[i], cmap='gray')
#     ax.axis('off')
plt.savefig('images/amalgama.png', bbox_inches='tight', pad_inches=0.1)
plt.show()

print(components_s.shape)
print(components.shape)
print(sp.linalg.norm(components_s - components), 'fro')
# Out:
# (100, 64, 64)
# (100, 64, 64)
# 14.142135 fro

# %% [markdown]
# ### Проверка методики определения принадлежности фото человеку через KNN на простом датасете

# %%
from sklearn.datasets import fetch_olivetti_faces
from sklearn.decomposition import TruncatedSVD
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report

# 1. Загрузка датасета
data = fetch_olivetti_faces(shuffle=True, random_state=42)
X = data.data  # Плоские массивы изображений (400, 4096)
y = data.target  # Метки классов (400,)

# 2. Разделение выборки на train и test
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=targets, random_state=42,
)

# 3. Применение SVD для уменьшения размерности
n_components = 100  # Число компонент для SVD
svd = TruncatedSVD(n_components=n_components, algorithm='arpack', random_state=42)
X_train_svd = svd.fit_transform(X_train)  # Обучающая выборка после SVD
X_test_svd = svd.transform(X_test)        # Тестовая выборка после SVD

# 4. Построение классификатора KNN
n_neighbors = 3  # Количество ближайших соседей
knn = KNeighborsClassifier(
    n_neighbors=n_neighbors,
    weights='distance',
    algorithm='auto',
    p=2,
    metric='minkowski',
    n_jobs=-1,
)
knn.fit(X_train_svd, y_train)

# 5. Предсказание классов на тестовой выборке
y_pred = knn.predict(X_test_svd)

# 6. Оценка качества алгоритма
print("Accuracy:", accuracy_score(y_test, y_pred))  # Общая точность
print("\nClassification Report:\n", classification_report(y_test, y_pred))  # Отчёт по метрикам
# Out:
# Accuracy: 0.925
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         2
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       1.00      0.50      0.67         2
#            9       1.00      0.50      0.67         2
#           10       1.00      1.00      1.00         2
#           11       1.00      1.00      1.00         2
#           12       1.00      1.00      1.00         2
#           13       1.00      1.00      1.00         2
#           14       1.00      1.00      1.00         2
#           15       0.50      0.50      0.50         2
#           16       1.00      1.00      1.00         2
#           17       0.67      1.00      0.80         2
#           18       1.00      1.00      1.00         2
#           19       1.00      1.00      1.00         2
#           20       1.00      1.00      1.00         2
#           21       1.00      1.00      1.00         2
#           22       1.00      1.00      1.00         2
#           23       0.67      1.00      0.80         2
#           24       1.00      1.00      1.00         2
#           25       1.00      1.00      1.00         2
#           26       1.00      1.00      1.00         2
#           27       1.00      1.00      1.00         2
#           28       1.00      1.00      1.00         2
#           29       1.00      1.00      1.00         2
#           30       1.00      1.00      1.00         2
#           31       1.00      1.00      1.00         2
#           32       1.00      1.00      1.00         2
#           33       1.00      1.00      1.00         2
#           34       1.00      1.00      1.00         2
#           35       1.00      0.50      0.67         2
#           36       1.00      1.00      1.00         2
#           37       1.00      1.00      1.00         2
#           38       1.00      1.00      1.00         2
#           39       0.50      1.00      0.67         2
#
#     accuracy                           0.93        80
#    macro avg       0.93      0.93      0.92        80
# weighted avg       0.93      0.93      0.92        80

# %% [markdown]
# ## Основной датасет face-recognition-dataset

# %%
# !pip3 install kagglehub --upgrade
# Out:
# Collecting kagglehub
#   Downloading kagglehub-0.3.5-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: packaging in /Users/artemon/.local/share/virtualenvs/project-mXI1-e8d/lib/python3.11/site-packages (from kagglehub) (24.2)
# Requirement already satisfied: requests in /Users/artemon/.local/share/virtualenvs/project-mXI1-e8d/lib/python3.11/site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in /Users/artemon/.local/share/virtualenvs/project-mXI1-e8d/lib/python3.11/site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/artemon/.local/share/virtualenvs/project-mXI1-e8d/lib/python3.11/site-packages (from requests->kagglehub) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/artemon/.local/share/virtualenvs/project-mXI1-e8d/lib/python3.11/site-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/artemon/.local/share/virtualenvs/project-mXI1-e8d/lib/python3.11/site-packages (from requests->kagglehub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/artemon/.local/share/virtualenvs/project-mXI1-e8d/lib/python3.11/site-packages (from requests->kagglehub) (2024.12.14)
# Downloading kagglehub-0.3.5-py3-none-any.whl (44 kB)
# Installing collected packages: kagglehub
# Successfully installed kagglehub-0.3.5
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("stoicstatic/face-recognition-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/stoicstatic/face-recognition-dataset?dataset_version_number=10...
# 100%|██████████| 181M/181M [01:49<00:00, 1.73MB/s]
# Extracting files...
# Path to dataset files: /Users/artemon/.cache/kagglehub/datasets/stoicstatic/face-recognition-dataset/versions/10

# %%
# Путь к директории с датасетом

path = r"/Users/artemon/.cache/kagglehub/datasets/stoicstatic/face-recognition-dataset/versions/10/Extracted Faces/Extracted Faces/"

# %% [markdown]
# ### Примеры изображений из датасета

# %%
import cv2
import os

class_paths = os.listdir(path)

# Визуализация нескольких изображений из датасета
fig, axes = plt.subplots(1, 10, figsize=(15, 5))
for i, ax in enumerate(axes):
    class_path = os.path.join(path, class_paths[i])
    image_names = os.listdir(class_path)
    image_name = os.path.join(class_path, image_names[0])
    img = cv2.imread(image_name)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    ax.imshow(img, cmap='gray', )
    ax.set_title(f"Label: {class_paths[i]}")
    ax.axis('off')

plt.savefig('images/main_faces.png', bbox_inches='tight', pad_inches=0.1)
plt.show()

# %% [markdown]
# ### Выгрузка датасета

# %%
np.array([936,1029,2010,1000]) * 2.6
# Out:
# array([2433.6, 2675.4, 5226. , 2600. ])

# %%
from PIL import Image
import os

# Функция для загрузки изображений и меток классов
def load_dataset(path):
    images = []
    targets = []

    # Обход папок с изображениями
    for class_name in os.listdir(path):
        class_path = os.path.join(path, class_name)
        if not os.path.isdir(class_path):
            continue

        try:
            label = int(class_name)  # Имя папки преобразуем в метку класса
        except ValueError:
            print(f"Пропускаем папку {class_name}, так как она не является номером класса.")
            continue

        for image_name in os.listdir(class_path):
            image_path = os.path.join(class_path, image_name)
            try:
                # Загружаем изображение и преобразуем его в RGB
                img = Image.open(image_path).convert("RGB")
                img_array = np.array(img, dtype=np.float64)

                # Переставляем оси в формат (C, H, W)
                img_array = np.transpose(img_array, (2, 0, 1))

                images.append(img_array)
                targets.append(label)
            except Exception as e:
                print(f"Ошибка при обработке изображения {image_path}: {e}")

    # Преобразуем списки в массивы numpy
    images = np.array(images, dtype=np.float64)
    targets = np.array(targets, dtype=np.int64)

    return images, targets

# Загрузка датасета
images, targets = load_dataset(path)

# Вывод размеров массивов
print("Размер массива images:", images.shape)
print("Размер массива targets:", targets.shape)
print("Колличество классов в датасете:", np.unique(targets).size)
# Out:
# Размер массива images: (6107, 3, 128, 128)
# Размер массива targets: (6107,)
# Колличество классов в датасете: 1324

# %% [markdown]
# ### Фильтрация, подготовка train и test частей

# %%
from sklearn.model_selection import train_test_split

# Фильтрация классов с количеством изображений > 20
unique_classes, class_counts = np.unique(targets, return_counts=True)
filtered_classes = unique_classes[class_counts > 20]

filtered_indices = np.isin(targets, filtered_classes)
images_filtered = images[filtered_indices]
targets_filtered = targets[filtered_indices]

# Проверяем, что каждый класс имеет достаточно данных для разбиения
unique_classes, class_counts = np.unique(targets_filtered, return_counts=True)
min_test_size = 1  # Минимальный размер тестовой выборки для каждого класса
if np.any(class_counts < 2 * min_test_size):
    raise ValueError("Некоторые классы имеют недостаточно данных для разбиения на train и test.")

print("Размер массива images после фильтрации:", images_filtered.shape)
print("Размер массива targets после фильтрации:", targets_filtered.shape)
print("Колличество классов в датасете после фильтрации:", np.unique(targets_filtered).size)

# Разбиение на train и test с учетом сохранения классов
train_indices, test_indices = train_test_split(
    np.arange(len(targets_filtered)), test_size=0.2, stratify=targets_filtered, random_state=42
)

images_train, images_test = images_filtered[train_indices], images_filtered[test_indices]
targets_train, targets_test = targets_filtered[train_indices], targets_filtered[test_indices]

# Преобразуем изображения для SVD (объединяем каналы и приводим к двумерному виду)
def flatten_images(images):
    N, C, H, W = images.shape
    return images.reshape(N, C * H * W)

images_train_flat = flatten_images(images_train)
images_test_flat = flatten_images(images_test)

# Вывод размеров массивов
print("Размер массива images_train_flat:", images_train_flat.shape)
print("Размер массива images_test_flat:", images_test_flat.shape)
print("Размер массива targets_train:", targets_train.shape)
print("Размер массива targets_test:", targets_test.shape)
# Out:
# Размер массива images после фильтрации: (1069, 3, 128, 128)
# Размер массива targets после фильтрации: (1069,)
# Колличество классов в датасете после фильтрации: 33
# Размер массива images_train_flat: (855, 49152)
# Размер массива images_test_flat: (214, 49152)
# Размер массива targets_train: (855,)
# Размер массива targets_test: (214,)

# %% [markdown]
# ### Сравнение нескольких алгоритмов SVD с одинаковыми начальными гиперпараметрами

# %%
from scipy.linalg import svd
from scipy.sparse.linalg import svds
from sklearn.utils.extmath import randomized_svd
from sklearn.decomposition import TruncatedSVD
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from time import time

n_neighbors = 20 # Число соседей в KNN
n_components = 500  # Число компонент для уменьшения размерности

# Список алгоритмов
algorithms = [
    ("Classic SVD (scipy.linalg.svd)", lambda X: svd(X, full_matrices=False, compute_uv=True)),
    ("Sparse SVD (scipy.sparse.linalg.svds)", lambda X: svds(X, k=n_components, return_singular_vectors=True)),
    ("Randomized SVD (sklearn.utils.extmath.randomized_svd)",
     lambda X: randomized_svd(X, n_components=n_components, random_state=42)),
    ("Truncated SVD (randomized, sklearn.decomposition.TruncatedSVD)",
     TruncatedSVD(n_components=n_components, algorithm="randomized", random_state=42)),
    ("Truncated SVD (arpack, sklearn.decomposition.TruncatedSVD)",
     TruncatedSVD(n_components=n_components, algorithm="arpack", random_state=42)),
]

# Замеры точности и времени
def compare_algorithms(algorithms, images_train_flat, images_test_flat, targets_train, targets_test, n_neighbors_list, n_components_list):
    results = []

    for i, (name, algorithm) in enumerate(algorithms):
        n_neighbors = n_neighbors_list[i]
        n_components = n_components_list[i]

        knn = KNeighborsClassifier(
            n_neighbors=n_neighbors,
            weights='distance',
            algorithm='auto',
            p=2,
            metric='minkowski',
            n_jobs=-1,
        )

        start_time = time()

        if "Truncated SVD" in name:
            # Метод TruncatedSVD из sklearn
            images_train_svd = algorithm.fit_transform(images_train_flat)
            images_test_svd = algorithm.transform(images_test_flat)
        elif "Classic SVD" in name:
            # Метод svd из scipy
            U_train, Sigma_train, VT_train = algorithm(images_train_flat)
            U_train, Sigma_train, VT_train = U_train[:, :n_components], Sigma_train[:n_components], VT_train[:n_components]
            images_train_svd = U_train * Sigma_train[np.newaxis, :]
            # Преобразование тестовых данных через VT_train
            images_test_svd = images_test_flat @ VT_train.T
        else:
            # Методы svds и randomized_svd из scipy
            U_train, Sigma_train, VT_train = algorithm(images_train_flat)
            images_train_svd = U_train * Sigma_train[np.newaxis, :]
            # Преобразование тестовых данных через VT_train
            images_test_svd = images_test_flat @ VT_train.T

        elapsed_time = time() - start_time

        # Обучение KNN
        knn.fit(images_train_svd, targets_train)
        predictions = knn.predict(images_test_svd)
        # Вычисление точности
        accuracy = accuracy_score(targets_test, predictions)

        # Сохраняем пару (точность, время)
        results.append((name, accuracy, elapsed_time))
        print(f"Алгоритм: {name}, Точность: {accuracy:.4f}, Время: {elapsed_time:.2f} сек,")

    return results

results = compare_algorithms(
    algorithms,
    images_train_flat,
    images_test_flat,
    targets_train,
    targets_test,
    [n_neighbors] * len(algorithms),
    [n_components] * len(algorithms),
)
# Out:
# Алгоритм: Classic SVD (scipy.linalg.svd), Точность: 0.1916, Время: 5.28 сек,
# Алгоритм: Sparse SVD (scipy.sparse.linalg.svds), Точность: 0.1916, Время: 26.51 сек,
# Алгоритм: Randomized SVD (sklearn.utils.extmath.randomized_svd), Точность: 0.1916, Время: 5.06 сек,
# Алгоритм: Truncated SVD (randomized, sklearn.decomposition.TruncatedSVD), Точность: 0.1916, Время: 6.41 сек,
# Алгоритм: Truncated SVD (arpack, sklearn.decomposition.TruncatedSVD), Точность: 0.1916, Время: 20.06 сек,

# %% [markdown]
# ### Визуализация результатов

# %%
# Построение графиков
def plot_results(results):
    names, accuracies, elapsed_times = zip(*results)

    plt.figure(figsize=(12, 6))

    # График точности
    plt.subplot(1, 2, 1)
    plt.barh(names, accuracies, color="lightgreen")
    plt.xlabel("Точность")
    plt.title("Точность классификации")

    # График времени
    plt.subplot(1, 2, 2)
    plt.barh(names, elapsed_times, color="skyblue")
    plt.xlabel("Время (сек)")
    plt.title("Время выполнения алгоритмов")

    plt.tight_layout()
    plt.show()

plot_results(results)

# %% [markdown]
# ## Оптимизация гипераметров при помощи Optuna

# %%
# !pip3 install optuna --upgrade
# Out:
# Collecting optuna
#   Downloading optuna-4.1.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.14.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /Users/artemon/.local/share/virtualenvs/project-mXI1-e8d/lib/python3.11/site-packages (from optuna) (2.2.0)
# Requirement already satisfied: packaging>=20.0 in /Users/artemon/.local/share/virtualenvs/project-mXI1-e8d/lib/python3.11/site-packages (from optuna) (24.2)
# Collecting sqlalchemy>=1.4.2 (from optuna)
#   Downloading SQLAlchemy-2.0.36-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.7 kB)
# Requirement already satisfied: tqdm in /Users/artemon/.local/share/virtualenvs/project-mXI1-e8d/lib/python3.11/site-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /Users/artemon/.local/share/virtualenvs/project-mXI1-e8d/lib/python3.11/site-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.8-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /Users/artemon/.local/share/virtualenvs/project-mXI1-e8d/lib/python3.11/site-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /Users/artemon/.local/share/virtualenvs/project-mXI1-e8d/lib/python3.11/site-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.1.0-py3-none-any.whl (364 kB)
# Downloading alembic-1.14.0-py3-none-any.whl (233 kB)
# Downloading SQLAlchemy-2.0.36-cp311-cp311-macosx_11_0_arm64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 3.1 MB/s eta 0:00:00a 0:00:01
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.8-py3-none-any.whl (78 kB)
# Installing collected packages: sqlalchemy, Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.8 alembic-1.14.0 colorlog-6.9.0 optuna-4.1.0 sqlalchemy-2.0.36
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import optuna
from sklearn.decomposition import randomized_svd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from time import time

# Многокритериальная целевая функция для оптимизации SVD с использованием Optuna
# Цель - максимизация точности и минимизация времени
def function(trial: optuna.trial.Trial, algorithm, images_train_flat, images_test_flat, targets_train, targets_test):
    # Гиперпараметры, которые мы хотим оптимизировать
    n_neighbors = trial.suggest_int('n_neighbors', 3, 30, log=True)  # Число соседей для KNN
    n_components = trial.suggest_int('n_components', 10, 1000, log=True)  # Количество компонент для SVD

    knn = KNeighborsClassifier(
        n_neighbors=n_neighbors,
        weights='distance',
        algorithm='auto',
        p=2,
        metric='minkowski',
        n_jobs=1,
    )

    start_time = time()

    if "Truncated SVD" in algorithm[0]:
        # Метод TruncatedSVD из sklearn
        images_train_svd = algorithm[1].fit_transform(images_train_flat)
        images_test_svd = algorithm[1].transform(images_test_flat)
    elif "Classic SVD" in algorithm[0]:
        # Метод svd из scipy
        U_train, Sigma_train, VT_train = algorithm[1](images_train_flat)
        U_train, Sigma_train, VT_train = U_train[:, :n_components], Sigma_train[:n_components], VT_train[:n_components]
        images_train_svd = U_train * Sigma_train[np.newaxis, :]
        # Преобразование тестовых данных через VT_train
        images_test_svd = images_test_flat @ VT_train.T
    else:
        # Методы svds и randomized_svd из scipy
        U_train, Sigma_train, VT_train = algorithm[1](images_train_flat)
        images_train_svd = U_train * Sigma_train[np.newaxis, :]
        # Преобразование тестовых данных через VT_train
        images_test_svd = images_test_flat @ VT_train.T

    elapsed_time = time() - start_time

    # Обучение KNN
    knn.fit(images_train_svd, targets_train)
    predictions = knn.predict(images_test_svd)
    # Вычисление точности
    accuracy = accuracy_score(targets_test, predictions)

    # Возвращаем пару (точность, время)
    return accuracy, elapsed_time

# %%
from functools import partial

n_trials=20

studies = []

for i, algorithm in enumerate(algorithms):

    objective = partial(
        function,
        algorithm=algorithm,
        images_train_flat=images_train_flat,
        images_test_flat=images_test_flat,
        targets_train=targets_train,
        targets_test=targets_test,
    )

    sampler = optuna.samplers.TPESampler(
        n_startup_trials=n_trials // 2,
        gamma=lambda n_trials: min(np.int64(np.ceil(0.1 * n_trials)), 25),
        n_ei_candidates=n_trials // 10,
        multivariate=True,
    )

    study = optuna.create_study(sampler=sampler, directions=['maximize', 'minimize'])

    study.optimize(objective, n_trials=n_trials, n_jobs=-1, timeout=1000, gc_after_trial=True)

    studies.append(study)
# Out:
# [I 2024-12-15 08:36:15,860] A new study created in memory with name: no-name-d78dd44d-4c4e-4038-85c8-ca8e34915d45
# [I 2024-12-15 08:37:12,648] Trial 1 finished with values: [0.16822429906542055, 56.76600694656372] and parameters: {'n_neighbors': 7, 'n_components': 10}.
# [I 2024-12-15 08:37:12,796] Trial 9 finished with values: [0.21495327102803738, 56.73877811431885] and parameters: {'n_neighbors': 15, 'n_components': 104}.
# [I 2024-12-15 08:37:12,932] Trial 5 finished with values: [0.2570093457943925, 56.738975048065186] and parameters: {'n_neighbors': 5, 'n_components': 280}.
# [I 2024-12-15 08:37:13,013] Trial 4 finished with values: [0.20093457943925233, 56.74174499511719] and parameters: {'n_neighbors': 5, 'n_components': 25}.
# [I 2024-12-15 08:37:13,116] Trial 7 finished with values: [0.2102803738317757, 56.73409700393677] and parameters: {'n_neighbors': 12, 'n_components': 254}.
# [I 2024-12-15 08:37:13,123] Trial 0 finished with values: [0.17289719626168223, 56.772496938705444] and parameters: {'n_neighbors': 5, 'n_components': 16}.
# [I 2024-12-15 08:37:29,004] Trial 6 finished with values: [0.19158878504672897, 56.899072885513306] and parameters: {'n_neighbors': 11, 'n_components': 49}.
# [I 2024-12-15 08:37:29,020] Trial 3 finished with values: [0.205607476635514, 56.907527923583984] and parameters: {'n_neighbors': 11, 'n_components': 373}.
# [I 2024-12-15 08:37:29,032] Trial 2 finished with values: [0.17289719626168223, 56.76870083808899] and parameters: {'n_neighbors': 27, 'n_components': 19}.
# [I 2024-12-15 08:37:29,153] Trial 8 finished with values: [0.24299065420560748, 56.89600896835327] and parameters: {'n_neighbors': 6, 'n_components': 153}.
# [I 2024-12-15 08:37:40,314] Trial 13 finished with values: [0.17289719626168223, 26.902756929397583] and parameters: {'n_neighbors': 3, 'n_components': 12}.
# [I 2024-12-15 08:37:56,865] Trial 10 finished with values: [0.17289719626168223, 16.239970207214355] and parameters: {'n_neighbors': 25, 'n_components': 21}.
# [I 2024-12-15 08:37:57,071] Trial 12 finished with values: [0.2616822429906542, 16.14985489845276] and parameters: {'n_neighbors': 3, 'n_components': 562}.
# [I 2024-12-15 08:37:57,078] Trial 14 finished with values: [0.2616822429906542, 11.077479839324951] and parameters: {'n_neighbors': 4, 'n_components': 62}.
# [I 2024-12-15 08:38:06,652] Trial 11 finished with values: [0.19158878504672897, 16.27410888671875] and parameters: {'n_neighbors': 20, 'n_components': 924}.
# [I 2024-12-15 08:38:06,734] Trial 18 finished with values: [0.27102803738317754, 16.750432014465332] and parameters: {'n_neighbors': 4, 'n_components': 81}.
# [I 2024-12-15 08:38:06,739] Trial 16 finished with values: [0.24766355140186916, 16.952785968780518] and parameters: {'n_neighbors': 5, 'n_components': 188}.
# [I 2024-12-15 08:38:06,880] Trial 15 finished with values: [0.2383177570093458, 16.95678210258484] and parameters: {'n_neighbors': 6, 'n_components': 702}.
# [I 2024-12-15 08:38:06,951] Trial 17 finished with values: [0.2383177570093458, 26.43875789642334] and parameters: {'n_neighbors': 3, 'n_components': 57}.
# [I 2024-12-15 08:38:07,016] Trial 19 finished with values: [0.21962616822429906, 9.785010814666748] and parameters: {'n_neighbors': 3, 'n_components': 32}.
# [I 2024-12-15 08:38:07,073] A new study created in memory with name: no-name-bd3dc288-e8a9-4a7f-a1b7-86b0ab9ac243
# [I 2024-12-15 08:38:38,282] Trial 0 finished with values: [0.2616822429906542, 31.188518285751343] and parameters: {'n_neighbors': 3, 'n_components': 19}.
# [I 2024-12-15 08:39:00,332] Trial 2 finished with values: [0.205607476635514, 53.24543213844299] and parameters: {'n_neighbors': 17, 'n_components': 339}.
# [I 2024-12-15 08:39:23,352] Trial 1 finished with values: [0.22429906542056074, 76.26591897010803] and parameters: {'n_neighbors': 10, 'n_components': 735}.
# [I 2024-12-15 08:39:43,345] Trial 3 finished with values: [0.18691588785046728, 96.2518138885498] and parameters: {'n_neighbors': 23, 'n_components': 14}.
# [I 2024-12-15 08:40:01,024] Trial 7 finished with values: [0.2336448598130841, 113.9290030002594] and parameters: {'n_neighbors': 9, 'n_components': 19}.
# [I 2024-12-15 08:40:18,867] Trial 5 finished with values: [0.2616822429906542, 131.78036093711853] and parameters: {'n_neighbors': 3, 'n_components': 181}.
# [I 2024-12-15 08:40:38,384] Trial 4 finished with values: [0.2383177570093458, 151.29815983772278] and parameters: {'n_neighbors': 8, 'n_components': 15}.
# [I 2024-12-15 08:40:59,557] Trial 6 finished with values: [0.2336448598130841, 172.4470682144165] and parameters: {'n_neighbors': 9, 'n_components': 618}.
# [I 2024-12-15 08:41:21,120] Trial 9 finished with values: [0.2383177570093458, 194.01227617263794] and parameters: {'n_neighbors': 6, 'n_components': 15}.
# [I 2024-12-15 08:41:42,596] Trial 8 finished with values: [0.2383177570093458, 215.50645518302917] and parameters: {'n_neighbors': 8, 'n_components': 26}.
# [I 2024-12-15 08:42:03,545] Trial 10 finished with values: [0.2757009345794392, 205.11155581474304] and parameters: {'n_neighbors': 4, 'n_components': 423}.
# [I 2024-12-15 08:42:25,052] Trial 11 finished with values: [0.19158878504672897, 204.61139512062073] and parameters: {'n_neighbors': 27, 'n_components': 202}.
# [I 2024-12-15 08:42:46,640] Trial 12 finished with values: [0.2616822429906542, 203.18275094032288] and parameters: {'n_neighbors': 3, 'n_components': 805}.
# [I 2024-12-15 08:43:07,149] Trial 13 finished with values: [0.20093457943925233, 203.664968252182] and parameters: {'n_neighbors': 18, 'n_components': 18}.
# [I 2024-12-15 08:43:28,244] Trial 14 finished with values: [0.2616822429906542, 207.12789297103882] and parameters: {'n_neighbors': 3, 'n_components': 126}.
# [I 2024-12-15 08:43:47,048] Trial 15 finished with values: [0.2757009345794392, 208.09380292892456] and parameters: {'n_neighbors': 4, 'n_components': 27}.
# [I 2024-12-15 08:44:06,218] Trial 16 finished with values: [0.2383177570093458, 207.73071432113647] and parameters: {'n_neighbors': 6, 'n_components': 139}.
# [I 2024-12-15 08:44:23,595] Trial 17 finished with values: [0.2570093457943925, 203.9481680393219] and parameters: {'n_neighbors': 5, 'n_components': 224}.
# [I 2024-12-15 08:44:41,361] Trial 18 finished with values: [0.18691588785046728, 200.13523626327515] and parameters: {'n_neighbors': 23, 'n_components': 10}.
# [I 2024-12-15 08:44:57,712] Trial 19 finished with values: [0.2616822429906542, 195.01313018798828] and parameters: {'n_neighbors': 3, 'n_components': 34}.
# [I 2024-12-15 08:44:57,790] A new study created in memory with name: no-name-856689ee-164a-40ad-a6db-06c983f7b2d7
# [I 2024-12-15 08:45:35,418] Trial 9 finished with values: [0.2336448598130841, 37.55827975273132] and parameters: {'n_neighbors': 7, 'n_components': 201}.
# [I 2024-12-15 08:45:36,398] Trial 8 finished with values: [0.2570093457943925, 38.31222581863403] and parameters: {'n_neighbors': 5, 'n_components': 785}.
# [I 2024-12-15 08:45:44,723] Trial 4 finished with values: [0.2336448598130841, 45.9740948677063] and parameters: {'n_neighbors': 6, 'n_components': 91}.
# [I 2024-12-15 08:45:44,827] Trial 7 finished with values: [0.2616822429906542, 46.81231212615967] and parameters: {'n_neighbors': 3, 'n_components': 211}.
# [I 2024-12-15 08:45:46,758] Trial 0 finished with values: [0.2336448598130841, 46.88487982749939] and parameters: {'n_neighbors': 9, 'n_components': 49}.
# [I 2024-12-15 08:45:46,866] Trial 2 finished with values: [0.205607476635514, 46.87802219390869] and parameters: {'n_neighbors': 17, 'n_components': 14}.
# [I 2024-12-15 08:45:46,973] Trial 3 finished with values: [0.205607476635514, 48.947516202926636] and parameters: {'n_neighbors': 11, 'n_components': 622}.
# [I 2024-12-15 08:45:47,113] Trial 6 finished with values: [0.2336448598130841, 48.94513511657715] and parameters: {'n_neighbors': 9, 'n_components': 290}.
# [I 2024-12-15 08:45:47,118] Trial 5 finished with values: [0.2336448598130841, 48.94729709625244] and parameters: {'n_neighbors': 6, 'n_components': 15}.
# [I 2024-12-15 08:45:48,300] Trial 1 finished with values: [0.18691588785046728, 47.646589040756226] and parameters: {'n_neighbors': 28, 'n_components': 14}.
# [I 2024-12-15 08:46:12,176] Trial 10 finished with values: [0.2616822429906542, 33.57623910903931] and parameters: {'n_neighbors': 3, 'n_components': 304}.
# [I 2024-12-15 08:46:16,331] Trial 11 finished with values: [0.2336448598130841, 37.82860779762268] and parameters: {'n_neighbors': 9, 'n_components': 460}.
# [I 2024-12-15 08:46:22,595] Trial 12 finished with values: [0.27102803738317754, 37.74240303039551] and parameters: {'n_neighbors': 4, 'n_components': 11}.
# [I 2024-12-15 08:46:24,908] Trial 13 finished with values: [0.2383177570093458, 37.87011981010437] and parameters: {'n_neighbors': 8, 'n_components': 59}.
# [I 2024-12-15 08:46:24,992] Trial 15 finished with values: [0.2616822429906542, 37.657536029815674] and parameters: {'n_neighbors': 3, 'n_components': 117}.
# [I 2024-12-15 08:46:25,073] Trial 16 finished with values: [0.2383177570093458, 36.91445517539978] and parameters: {'n_neighbors': 8, 'n_components': 13}.
# [I 2024-12-15 08:46:25,160] Trial 17 finished with values: [0.2570093457943925, 36.054455041885376] and parameters: {'n_neighbors': 5, 'n_components': 898}.
# [I 2024-12-15 08:46:25,235] Trial 14 finished with values: [0.2336448598130841, 38.13041400909424] and parameters: {'n_neighbors': 6, 'n_components': 19}.
# [I 2024-12-15 08:46:25,311] Trial 18 finished with values: [0.205607476635514, 35.291930198669434] and parameters: {'n_neighbors': 16, 'n_components': 533}.
# [I 2024-12-15 08:46:25,384] Trial 19 finished with values: [0.27102803738317754, 35.36089015007019] and parameters: {'n_neighbors': 4, 'n_components': 401}.
# [I 2024-12-15 08:46:25,453] A new study created in memory with name: no-name-f3ae2d18-bace-47d8-8adb-f2a80129ec1e
# [I 2024-12-15 08:47:11,902] Trial 4 finished with values: [0.17757009345794392, 46.3675491809845] and parameters: {'n_neighbors': 21, 'n_components': 974}.
# [I 2024-12-15 08:47:18,929] Trial 6 finished with values: [0.205607476635514, 52.64922475814819] and parameters: {'n_neighbors': 11, 'n_components': 11}.
# [I 2024-12-15 08:47:20,047] Trial 9 finished with values: [0.2383177570093458, 54.0492467880249] and parameters: {'n_neighbors': 8, 'n_components': 17}.
# [I 2024-12-15 08:47:22,320] Trial 1 finished with values: [0.27102803738317754, 54.37103819847107] and parameters: {'n_neighbors': 4, 'n_components': 11}.
# [I 2024-12-15 08:47:22,344] Trial 8 finished with values: [0.2570093457943925, 54.80809211730957] and parameters: {'n_neighbors': 5, 'n_components': 175}.
# [I 2024-12-15 08:47:22,695] Trial 0 finished with values: [0.17757009345794392, 56.79274892807007] and parameters: {'n_neighbors': 23, 'n_components': 480}.
# [I 2024-12-15 08:47:23,510] Trial 7 finished with values: [0.2616822429906542, 57.12575316429138] and parameters: {'n_neighbors': 3, 'n_components': 24}.
# [I 2024-12-15 08:47:26,420] Trial 5 finished with values: [0.2102803738317757, 57.132896900177] and parameters: {'n_neighbors': 10, 'n_components': 279}.
# [I 2024-12-15 08:47:26,425] Trial 3 finished with values: [0.27102803738317754, 57.13406801223755] and parameters: {'n_neighbors': 4, 'n_components': 187}.
# [I 2024-12-15 08:47:26,578] Trial 2 finished with values: [0.18691588785046728, 57.135525941848755] and parameters: {'n_neighbors': 28, 'n_components': 214}.
# [I 2024-12-15 08:47:57,664] Trial 10 finished with values: [0.27102803738317754, 42.4949848651886] and parameters: {'n_neighbors': 4, 'n_components': 116}.
# [I 2024-12-15 08:48:00,162] Trial 11 finished with values: [0.2383177570093458, 40.89466691017151] and parameters: {'n_neighbors': 8, 'n_components': 28}.
# [I 2024-12-15 08:48:07,265] Trial 12 finished with values: [0.2102803738317757, 46.06412100791931] and parameters: {'n_neighbors': 12, 'n_components': 145}.
# [I 2024-12-15 08:48:09,199] Trial 16 finished with values: [0.2383177570093458, 43.74963188171387] and parameters: {'n_neighbors': 8, 'n_components': 35}.
# [I 2024-12-15 08:48:09,311] Trial 19 finished with values: [0.2616822429906542, 42.39503312110901] and parameters: {'n_neighbors': 3, 'n_components': 34}.
# [I 2024-12-15 08:48:09,389] Trial 14 finished with values: [0.2336448598130841, 46.38940119743347] and parameters: {'n_neighbors': 9, 'n_components': 129}.
# [I 2024-12-15 08:48:09,465] Trial 13 finished with values: [0.19158878504672897, 46.62246131896973] and parameters: {'n_neighbors': 20, 'n_components': 103}.
# [I 2024-12-15 08:48:09,466] Trial 15 finished with values: [0.2616822429906542, 46.60007095336914] and parameters: {'n_neighbors': 3, 'n_components': 160}.
# [I 2024-12-15 08:48:09,708] Trial 17 finished with values: [0.2616822429906542, 43.193976163864136] and parameters: {'n_neighbors': 3, 'n_components': 152}.
# [I 2024-12-15 08:48:09,781] Trial 18 finished with values: [0.20093457943925233, 43.19963216781616] and parameters: {'n_neighbors': 18, 'n_components': 142}.
# [I 2024-12-15 08:48:09,849] A new study created in memory with name: no-name-59e28440-4a5e-45d2-a7d1-0e3a9e487a4c
# [I 2024-12-15 08:48:27,654] Trial 0 finished with values: [0.20093457943925233, 17.766789197921753] and parameters: {'n_neighbors': 14, 'n_components': 11}.
# [I 2024-12-15 08:48:44,701] Trial 2 finished with values: [0.2336448598130841, 34.84049892425537] and parameters: {'n_neighbors': 7, 'n_components': 162}.
# [I 2024-12-15 08:49:01,714] Trial 3 finished with values: [0.2570093457943925, 51.84186506271362] and parameters: {'n_neighbors': 5, 'n_components': 12}.
# [I 2024-12-15 08:49:18,663] Trial 6 finished with values: [0.2570093457943925, 68.8013231754303] and parameters: {'n_neighbors': 5, 'n_components': 241}.
# [I 2024-12-15 08:49:36,260] Trial 5 finished with values: [0.2757009345794392, 86.39902186393738] and parameters: {'n_neighbors': 4, 'n_components': 134}.
# [I 2024-12-15 08:49:54,070] Trial 7 finished with values: [0.205607476635514, 104.19415807723999] and parameters: {'n_neighbors': 16, 'n_components': 164}.
# [I 2024-12-15 08:50:11,618] Trial 9 finished with values: [0.2336448598130841, 121.74685907363892] and parameters: {'n_neighbors': 7, 'n_components': 221}.
# [I 2024-12-15 08:50:29,787] Trial 4 finished with values: [0.2616822429906542, 139.8276379108429] and parameters: {'n_neighbors': 3, 'n_components': 189}.
# [I 2024-12-15 08:50:49,125] Trial 8 finished with values: [0.2383177570093458, 159.2157769203186] and parameters: {'n_neighbors': 6, 'n_components': 44}.
# [I 2024-12-15 08:51:07,352] Trial 1 finished with values: [0.2757009345794392, 177.49634099006653] and parameters: {'n_neighbors': 4, 'n_components': 10}.
# [I 2024-12-15 08:51:24,620] Trial 10 finished with values: [0.17289719626168223, 176.87614011764526] and parameters: {'n_neighbors': 22, 'n_components': 159}.
# [I 2024-12-15 08:51:43,446] Trial 11 finished with values: [0.2383177570093458, 178.6625051498413] and parameters: {'n_neighbors': 8, 'n_components': 26}.
# [I 2024-12-15 08:52:01,618] Trial 12 finished with values: [0.17757009345794392, 179.78704977035522] and parameters: {'n_neighbors': 21, 'n_components': 148}.
# [I 2024-12-15 08:52:20,165] Trial 13 finished with values: [0.20093457943925233, 181.40953516960144] and parameters: {'n_neighbors': 18, 'n_components': 21}.
# [I 2024-12-15 08:52:38,221] Trial 14 finished with values: [0.2570093457943925, 181.85720133781433] and parameters: {'n_neighbors': 5, 'n_components': 266}.
# [I 2024-12-15 08:52:55,743] Trial 15 finished with values: [0.19158878504672897, 181.5809450149536] and parameters: {'n_neighbors': 24, 'n_components': 77}.
# [I 2024-12-15 08:53:12,931] Trial 16 finished with values: [0.2383177570093458, 181.22689700126648] and parameters: {'n_neighbors': 6, 'n_components': 493}.
# [I 2024-12-15 08:53:30,364] Trial 17 finished with values: [0.2383177570093458, 180.417631149292] and parameters: {'n_neighbors': 6, 'n_components': 897}.
# [I 2024-12-15 08:53:47,348] Trial 18 finished with values: [0.2570093457943925, 178.05054807662964] and parameters: {'n_neighbors': 5, 'n_components': 33}.
# [I 2024-12-15 08:54:04,101] Trial 19 finished with values: [0.2383177570093458, 176.66728687286377] and parameters: {'n_neighbors': 6, 'n_components': 19}.

# %% [markdown]
# ### Оптимальные гиперпараметры для нескольких алгоритмов SVD

# %%
def get_best_trial(study, best_option='score'):

    if len(study.trials) == 1:
        return study.trials[0].params, study.trials[0].values

    best_num = 0
    best_values = study.trials[0].values

    for i, trial in enumerate(study.trials):
        if best_option == 'score':
            if trial.values[0] > best_values[0]:
                best_values = trial.values
                best_num = i
            elif np.isclose(trial.values[0], best_values[0], atol=1e-5) and trial.values[1] < best_values[1]:
                best_values = trial.values
                best_num = i
        elif best_option == 'time':
            if trial.values[1] < best_values[1]:
                best_values = trial.values
                best_num = i
            elif np.isclose(trial.values[1], best_values[1], atol=1e-4) and trial.values[0] > best_values[0]:
                best_values = trial.values
                best_num = i
        else:
            raise NotImplementedError

    return study.trials[best_num].params, best_values

best_params = []

for i, study in enumerate(studies):
    params, (accuracy, elapsed_time) = get_best_trial(study)
    name = algorithms[i][0]
    keys = list(params.keys())
    list_params = []
    print(f"Алгоритм: {name},", end=' ')
    for key in keys:
        list_params.append(params[key])
        print(f"{key}: {params[key]}", end=', ')
    best_params.append(list_params)
    print()
# Out:
# Алгоритм: Classic SVD (scipy.linalg.svd), n_neighbors: 4, n_components: 81,
# Алгоритм: Sparse SVD (scipy.sparse.linalg.svds), n_neighbors: 4, n_components: 423,
# Алгоритм: Randomized SVD (sklearn.utils.extmath.randomized_svd), n_neighbors: 4, n_components: 401,
# Алгоритм: Truncated SVD (randomized, sklearn.decomposition.TruncatedSVD), n_neighbors: 4, n_components: 116,
# Алгоритм: Truncated SVD (arpack, sklearn.decomposition.TruncatedSVD), n_neighbors: 4, n_components: 134,

# %% [markdown]
# ### Сравнение нескольких алгоритмов SVD с оптимальными гиперпараметрами

# %%
import numpy as np

np.linalg.svd(np.array([
    [0, 1.2],
    [0.9, 0]
]))
# Out:
# SVDResult(U=array([[-1.,  0.],
#        [ 0., -1.]]), S=array([1.2, 0.9]), Vh=array([[-0., -1.],
#        [-1., -0.]]))

# %%
best_results = compare_algorithms(
    algorithms,
    images_train_flat,
    images_test_flat,
    targets_train,
    targets_test,
    *zip(*best_params),
)
# Out:
# Алгоритм: Classic SVD (scipy.linalg.svd), Точность: 0.2710, Время: 5.09 сек,
# Алгоритм: Sparse SVD (scipy.sparse.linalg.svds), Точность: 0.2757, Время: 24.60 сек,
# Алгоритм: Randomized SVD (sklearn.utils.extmath.randomized_svd), Точность: 0.2710, Время: 5.17 сек,
# Алгоритм: Truncated SVD (randomized, sklearn.decomposition.TruncatedSVD), Точность: 0.2710, Время: 6.47 сек,
# Алгоритм: Truncated SVD (arpack, sklearn.decomposition.TruncatedSVD), Точность: 0.2757, Время: 17.70 сек,

# %% [markdown]
# ### Визуализация результатов

# %%
def plot_results(results):
    names, accuracies, elapsed_times = zip(*results)

    plt.figure(figsize=(12, 6))

    # График точности
    plt.subplot(1, 2, 1)
    plt.barh(names, accuracies, color="lightgreen")
    plt.xlabel("Точность")
    plt.title("Точность классификации")

    # График времени
    plt.subplot(1, 2, 2)
    plt.barh(names, elapsed_times, color="skyblue")
    plt.xlabel("Время (сек)")
    plt.title("Время выполнения алгоритмов")

    plt.tight_layout()
    plt.show()

# %%
plot_results(best_results)

# %% [markdown]
# ### Визуализация результатов оптимизации

# %%
# !pip3 install kaleido --upgrade
# Out:
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-macosx_11_0_arm64.whl.metadata (15 kB)
# Downloading kaleido-0.2.1-py2.py3-none-macosx_11_0_arm64.whl (85.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.8/85.8 MB 1.1 MB/s eta 0:00:0000:0100:030m
# Installing collected packages: kaleido
# Successfully installed kaleido-0.2.1
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
from optuna.visualization import plot_pareto_front

for i, study in enumerate(studies):
    print("Алгоритм:", algorithms[i][0])
    fig = plot_pareto_front(study, include_dominated_trials=False, target_names=['accuracy', 'elapsed_time'])
    fig.show()
    # fig.write_image("pareto_front.png", scale=2)
# Out:
# Алгоритм: Classic SVD (scipy.linalg.svd)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/share/virtualenvs/project-mXI1-e8d/lib/python3.11/site-packages/optuna/visualization/_plotly_imports.py:7
#       6 with try_import() as _imports:
# ----> 7     import plotly
#       8     from plotly import __version__ as plotly_version
#
# ModuleNotFoundError: No module named 'plotly'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[45], line 5
#       3 for i, study in enumerate(studies):
#       4     print("Алгоритм:", algorithms[i][0])
# ----> 5     fig = plot_pareto_front(study, include_dominated_trials=False, target_names=['accuracy', 'elapsed_time'])
#       6     fig.show()
#       7     # fig.write_image("pareto_front.png", scale=2)
#
# File ~/.local/share/virtualenvs/project-mXI1-e8d/lib/python3.11/site-packages/optuna/visualization/_pareto_front.py:101, in plot_pareto_front(study, target_names, include_dominated_trials, axis_order, constraints_func, targets)
#      37 def plot_pareto_front(
#      38     study: Study,
#      39     *,
#    (...)
#      44     targets: Callable[[FrozenTrial], Sequence[float]] | None = None,
#      45 ) -> "go.Figure":
#      46     """Plot the Pareto front of a study.
#      47
#      48     .. seealso::
#    (...)
#      98         A :class:`plotly.graph_objects.Figure` object.
#      99     """
# --> 101     _imports.check()
#     103     info = _get_pareto_front_info(
#     104         study, target_names, include_dominated_trials, axis_order, constraints_func, targets
#     105     )
#     106     return _get_pareto_front_plot(info)
#
# File ~/.local/share/virtualenvs/project-mXI1-e8d/lib/python3.11/site-packages/optuna/_imports.py:95, in _DeferredImportExceptionContextManager.check(self)
#      93 if self._deferred is not None:
#      94     exc_value, message = self._deferred
# ---> 95     raise ImportError(message) from exc_value
#
# ImportError: Tried to import 'plotly' but failed. Please make sure that the package is installed correctly to use this feature. Actual error: No module named 'plotly'.

# %% [markdown]
# # LDA

# %% [markdown]
# **1. Найдем формулы для распределения $q(t_d = t)$:**
#
# *будем называть семейство всех дельта функций как $\{ \delta \}$*
#
# $$p(t \, | \, W, \Phi, \pi) = \frac{p(W \, | \, t, \Phi) p(t \, | \, \pi)}{\sum_{t^\prime \in T} p(W \, | \, t^\prime, \Phi) p(t^\prime \, | \, \pi)} =  \frac{p(W \, | \, t, \Phi) p(t \, | \, \pi)}{\texttt{Const}} = \left\{s_1, s_2, \dots, s_T \right\} = \left\{\frac{\hat{s}_1}{\texttt{Const}}, \frac{\hat{s}_2}{\texttt{Const}}, \dots, \frac{\hat{s}_T}{\texttt{Const}} \right\}$$
#
# $$\Rightarrow KL(q(t) \| p(t \, | \, W, \Phi, \pi)) = -1 \cdot \log p(t_i \, | \, W, \Phi, \pi) \rightarrow \min\limits_{q(t) \in \{ \delta \}} \Rightarrow q(t) = \delta\left(t - arg \min_\ell \left\{ \log\hat{s}_1, \log\hat{s}_2, \dots, \log\hat{s}_T \right\} \right)$$
#
# **2. Найдем формулы обновления для $\Phi, \pi$:**
#
# $$\mathbb{E}_{q(t)} \log p(W, t \, | \, \Phi, \pi) = \sum_{d=1}^D \left\{\sum_{n=1}^{N_d} \left\{ \log \Phi_{t_d w_dn} \right\} + \log \pi_{t_d}\right\}$$
#
# Используем ККТ:
# - Пусть $\Alpha \in \mathbb{Z_+}^{T \times W} = \{ \# w_t \}$ число слов $w$ в каждой теме встретившееся в обучающей выбобрке
# - Пусть $\Beta \in \mathbb{Z_+}^{T} = \{ \# t \}$ число выборов темы $t$ на e-step
#
# $$\mathcal{L}_\phi = \sum_{t=1}^T \sum_{w=1}^V \alpha_{tw} \log \phi_{tw} - \sum_{t=1}^T \lambda_t \left( \sum_{w=1}^V \phi_{tw} - 1 \right) + C \Rightarrow \nabla_{\phi_{tw}} \mathcal{L} = \frac{\alpha_{tw}}{\phi_{tw}} - \lambda_t = 0 \Rightarrow \phi_{tw} = \frac{\alpha_{tw}}{\lambda_t} \Rightarrow \forall t: \,\, 1 = \sum_{w=1}^V \phi_{tw} = \sum_{w=1}^V \frac{\alpha_{tw}}{\lambda_t} \Rightarrow \lambda_t = \sum_{\ell=1}^V \alpha_{t\ell}$$
#
# $$\mathcal{L}_\pi = \sum_{t=1}^T \beta_t \log \pi_t - \mu \left(\sum_{t=1}^T \pi_t - 1\right) + C \Rightarrow \nabla_{\pi_t} \mathcal{L} = \frac{\beta_t}{\pi_t} - \mu = 0 \Rightarrow \pi_t = \frac{\beta_t}{\mu} \Rightarrow 1 = \sum_{t=1}^T \pi_t = \sum_{t=1}^T \frac{\beta_t}{\mu} \Rightarrow \mu = \sum_{\ell=1}^T \beta_\ell$$
#
# Таким образом получаем:
#
# $$\phi_{tw} = \frac{\alpha_{tw}}{\sum_{\ell}^V \alpha_{t\ell}} \quad\quad \pi_t = \frac{\beta_t}{\sum_{\ell = 1}^T \beta_\ell}$$
#
#
# **3. Выведем ELBO**
#
# $$\text{\textbf{ELBO}} = A * \log \Phi + B^\intercal \log \pi - \cancel{H(q(t))} \,\,\,\,\,\, \{\text{  вырожденное распределение}\}$$

# %% [markdown]
# Ошибки по параметрам начальных инициализаций! => Есть несколько явных оптимумов?
#
# ![image.png](attachment:image.png)

# %%
from matplotlib import pyplot as plt
from scipy.special import softmax 
import seaborn as sns

fig, axis = plt.subplot_mosaic([['matrix_view', 'histplot'],
                                ['matrix_view', 'freq_words']])
fig.set_figheight(8)
fig.set_figwidth(12)

axis['matrix_view'].matshow(freqs[:80])
axis['matrix_view'].set_yticklabels([])
axis['matrix_view'].set_xticklabels([])
axis['matrix_view'].set_ylabel('первые 40 документов')
axis['matrix_view'].set_xlabel('темы')

data = pd.DataFrame(np.log(freqs))

sns.kdeplot(data, ax=axis['histplot'])
axis['histplot'].legend([f'Тема #{i+1}' for i in range(10)], ncol=1, bbox_to_anchor=(1, 1.04))
axis['histplot'].set_title('Распределение тем в документах')

sns.barplot(most_common_occurance, ax=axis['freq_words'])
axis['freq_words'].set_xticklabels([f'Тема #{i+1}' for i in range(10)], rotation=70)
axis['freq_words'].set_title('Частота встречаемости 30 самых частых слов в темах')

fig.text(0.91, 0.5, 'Статистики', ha='center')
for m, s, i in zip(means, std, range(10)):
    fig.text(0.96, 0.46 - i*0.03, r'$\mathbb{E}f_{' + str(i+1) + r'}=$'+f'{m:.3f}' + r'$\,\, \mathbb{D}f_{' + str(i+1) + r'}=$'+f'{s:.3f}', ha='center')

fig.tight_layout()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from tabulate import tabulate

def print_topics(count_vectorizer, phi_matrix, n_top_words, drop_columns=None):
    words = count_vectorizer.get_feature_names_out()
    if drop_columns is not None:
        words = words[~drop_columns]
    
    table = tabulate(
        [["Topic #{}".format(i+1)] + [words[i] for i in topic.argsort()[:-n_top_words - 1:-1]] for i, topic in enumerate(phi_matrix)],
        headers=["Topic"] + [f'Word #{i+1}' for i in range(n_top_words)],
        tablefmt="rounded_grid"
    )
    print(table)
